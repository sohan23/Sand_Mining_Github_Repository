# %% [markdown]
# <a href="https://colab.research.google.com/github/sohan23/SandMining_final/blob/main/tree/master/Template%2520Folder/1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os

def save_notebook():
  """Saves the current notebook to GitHub."""
  notebook_name = os.path.basename(os.getcwd())
  git_repo = "https://github.com/sohan23/SandMining_final.git"
  command = "git add ."
  command += " && git commit -m 'Autosave'"
  command += " && git push"
  os.system(command)

if __name__ == "__main__":
  save_notebook()
